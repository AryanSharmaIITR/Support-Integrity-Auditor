# %%
import pandas as pd

# %%
df=pd.read_csv("../New_df.csv")

# %%
df.Issue_Category.value_counts()
# Out:
# Issue_Category
# Technical          5918
# Billing            5036
# Account            4081
# General Inquiry    3925
# Fraud              1040
# Name: count, dtype: int64

# %%
df["Issue_Category_num"] = df.Issue_Category.map({"General Inquiry":0,"Technical": 1, "Account":2, "Billing": 3,"Fraud":4})

# %%
df.severity.value_counts()
# Out:
# severity
# P3    17834
# P2     1918
# P0      145
# P4       94
# P1        9
# Name: count, dtype: int64

# %%
df["severity"] = df["severity"].map({"P0":"Critical","P1":"High","P2":"Medium","P3":"Low","P4":"Low"})

# %%
df[df["Issue_Category_num"]==0].severity.value_counts()/df.severity.value_counts(), df[df["Issue_Category_num"]==0].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[df["Issue_Category_num"]==0].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Critical         NaN
#  High             NaN
#  Low         0.218931
#  Medium           NaN
#  Name: count, dtype: float64,
#  Priority_Level
#  Critical         NaN
#  High        0.113876
#  Low         0.255054
#  Medium      0.207133
#  Name: count, dtype: float64,
#  result_emb
#  Crit      0.183525
#  High      0.081564
#  Low       0.529400
#  Medium    0.004036
#  Name: count, dtype: float64)

# %%
df[df["Resolution_Time_Hours"]<24].severity.value_counts()/df.severity.value_counts(), df[df["Resolution_Time_Hours"]<24].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[df["Resolution_Time_Hours"]<24].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Low         0.442046
#  Medium      0.500521
#  Critical    0.634483
#  High        0.555556
#  Name: count, dtype: float64,
#  Priority_Level
#  Critical    0.863636
#  High        0.607436
#  Low         0.370918
#  Medium      0.386262
#  Name: count, dtype: float64,
#  result_emb
#  Crit      0.530546
#  High      0.411963
#  Low       0.408269
#  Medium    0.494667
#  Name: count, dtype: float64)

# %%
df[df["Issue_Category_num"]==1].severity.value_counts()/df.severity.value_counts(), df[df["Issue_Category_num"]==1].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[df["Issue_Category_num"]==1].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Low         0.222501
#  Medium      0.962461
#  Critical    0.551724
#  High        0.333333
#  Name: count, dtype: float64,
#  Priority_Level
#  Critical    0.448382
#  High        0.511710
#  Low         0.151633
#  Medium      0.319419
#  Name: count, dtype: float64,
#  result_emb
#  Crit      0.343766
#  High      0.116779
#  Low       0.040308
#  Medium    0.994235
#  Name: count, dtype: float64)

# %%
df[(df["Resolution_Time_Hours"]>24)&(df["Resolution_Time_Hours"]<48)].severity.value_counts()/df.severity.value_counts(), df[(df["Resolution_Time_Hours"]>24)&(df["Resolution_Time_Hours"]<48)].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[(df["Resolution_Time_Hours"]>24)&(df["Resolution_Time_Hours"]<48)].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Low         0.223617
#  Medium      0.217935
#  Critical    0.186207
#  High        0.222222
#  Name: count, dtype: float64,
#  Priority_Level
#  Low         0.233411
#  Medium      0.226024
#  High        0.235948
#  Critical    0.106317
#  Name: count, dtype: float64,
#  result_emb
#  High      0.235241
#  Low       0.221276
#  Crit      0.204056
#  Medium    0.218795
#  Name: count, dtype: float64)

# %%
df[(df["Resolution_Time_Hours"]>48)&(df["Resolution_Time_Hours"]<72)].severity.value_counts()/df.severity.value_counts(), df[(df["Resolution_Time_Hours"]>48)&(df["Resolution_Time_Hours"]<72)].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[(df["Resolution_Time_Hours"]>48)&(df["Resolution_Time_Hours"]<72)].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Critical    0.082759
#  High             NaN
#  Low         0.123550
#  Medium      0.105318
#  Name: count, dtype: float64,
#  Priority_Level
#  Low         0.140617
#  Medium      0.135931
#  High        0.087822
#  Critical    0.011556
#  Name: count, dtype: float64,
#  result_emb
#  Crit      0.093640
#  High      0.130114
#  Low       0.136298
#  Medium    0.113577
#  Name: count, dtype: float64)

# %%
df[(df["Resolution_Time_Hours"]>72)&(df["Resolution_Time_Hours"]<145)].severity.value_counts()/df.severity.value_counts(), df[(df["Resolution_Time_Hours"]>72)&(df["Resolution_Time_Hours"]<140)].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[(df["Resolution_Time_Hours"]>72)&(df["Resolution_Time_Hours"]<145)].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Low         0.186691
#  Medium      0.145985
#  Critical    0.068966
#  High        0.222222
#  Name: count, dtype: float64,
#  Priority_Level
#  Low         0.229912
#  Medium      0.224967
#  High        0.046546
#  Critical    0.002311
#  Name: count, dtype: float64,
#  result_emb
#  High      0.197178
#  Low       0.210264
#  Crit      0.147471
#  Medium    0.148458
#  Name: count, dtype: float64)

# %%
df[df["Issue_Category_num"]==2].severity.value_counts()/df.severity.value_counts(), df[df["Issue_Category_num"]==2].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[df["Issue_Category_num"]==2].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Critical         NaN
#  High        0.111111
#  Low         0.223672
#  Medium      0.036496
#  Name: count, dtype: float64,
#  Priority_Level
#  Critical         NaN
#  High        0.118560
#  Low         0.266200
#  Medium      0.214267
#  Name: count, dtype: float64,
#  result_emb
#  Crit      0.163996
#  High      0.199379
#  Low       0.391648
#  Medium    0.000288
#  Name: count, dtype: float64)

# %%
df[df["Issue_Category_num"]==3].severity.value_counts()/df.severity.value_counts(), df[df["Issue_Category_num"]==3].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[df["Issue_Category_num"]==3].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Critical         NaN
#  High        0.222222
#  Low         0.280678
#  Medium      0.001043
#  Name: count, dtype: float64,
#  Priority_Level
#  Critical         NaN
#  High        0.161007
#  Low         0.327112
#  Medium      0.259181
#  Name: count, dtype: float64,
#  result_emb
#  Crit      0.064096
#  High      0.599171
#  Low       0.030542
#  Medium    0.001441
#  Name: count, dtype: float64)

# %%
df[df["Issue_Category_num"]==4].severity.value_counts()/df.severity.value_counts(), df[df["Issue_Category_num"]==4].Priority_Level.value_counts()/df.Priority_Level.value_counts(), df[df["Issue_Category_num"]==4].result_emb.value_counts()/df.result_emb.value_counts()
# Out:
# (severity
#  Critical    0.448276
#  High        0.333333
#  Low         0.054217
#  Medium           NaN
#  Name: count, dtype: float64,
#  Priority_Level
#  Critical    0.551618
#  High        0.094848
#  Low              NaN
#  Medium           NaN
#  Name: count, dtype: float64,
#  result_emb
#  Crit      0.244617
#  High      0.003107
#  Low       0.008103
#  Medium         NaN
#  Name: count, dtype: float64)
